# %% [markdown]
# This file plots the single cell posterior predictive plots, and higher order moments.

# %%
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import data_preprocessing.ABC_priors_and_functions as ABC
import data_preprocessing.plotting_functions as ABC_plot

SMALL_SIZE = 12
MEDIUM_SIZE = 16
BIGGER_SIZE = 16

plt.rc('font', size=BIGGER_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
plt.rcParams['font.family'] = 'Arial'

# %% [markdown]
# We begin with the single cell posterior predictive plots. Select which model you wish to view by uncommenting the appropriate simulator in the below codeblock. If you wish to simulate the posterior predictives from scratch, set load = False (warning: this can take up to an hour to run).

# %%
simulator = "three population pulse"
#simulator = "dispersed three population pulse"
#simulator = "three population chase"

load = True

# %%
if simulator == "three population pulse":
    if load:
        nucleoid_1hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_1hr.npy")
        nucleoid_3hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_3hr.npy")
        nucleoid_7hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_7hr.npy")
        nucleoid_24hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_24hr.npy")
        edu_1hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_1hr.npy")
        edu_3hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_3hr.npy")
        edu_7hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_7hr.npy")
        edu_24hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_24hr.npy")
    
    if not load:
        nucleoid_1hr, nucleoid_3hr, nucleoid_7hr, nucleoid_24hr, edu_1hr, edu_3hr, edu_7hr, edu_24hr = ABC.single_cell_posterior_predictive(num_samples = 500, inference_portion = "pulse", dispersed = False)


elif simulator == "dispersed three population pulse":
    if load:
        nucleoid_1hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_1hr_dispersed.npy")
        nucleoid_7hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_7hr_dispersed.npy")
        nucleoid_24hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/nucleoid_24hr_dispersed.npy")
        edu_1hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_1hr_dispersed.npy")
        edu_3hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_3hr_dispersed.npy")
        edu_7hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_7hr_dispersed.npy")
        edu_24hr = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/pulse/edu_24hr_dispersed.npy")
    
    if not load:
        nucleoid_1hr, nucleoid_3hr, nucleoid_7hr, nucleoid_24hr, edu_1hr, edu_3hr, edu_7hr, edu_24hr = ABC.single_cell_posterior_predictive(num_samples = 500, inference_portion = "pulse", dispersed = True)
    
elif simulator == "three population chase":
    if load:
        nucleoid_0dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/nucleoid_0dy.npy")
        nucleoid_1dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/nucleoid_1dy.npy")
        nucleoid_2dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/nucleoid_2dy.npy")
        nucleoid_4dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/nucleoid_4dy.npy")
        edu_0dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/edu_0dy.npy")
        edu_1dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/edu_1dy.npy")
        edu_2dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/edu_2dy.npy")
        edu_4dy = np.load("./data_preprocessing/simulated_single_cell_posterior_predictive_data/chase/edu_4dy.npy")
    if not load:
        nucleoid_0dy, nucleoid_1dy, nucleoid_2dy, nucleoid_4dy, edu_0dy, edu_1dy, edu_2dy, edu_4dy = ABC.single_cell_posterior_predictive(num_samples = 500, inference_portion = "chase")

# %%
if simulator == "three population pulse" or simulator == "dispersed three population pulse":
    ABC_plot.single_cell_posterior_predictive_pulse(nucleoid_1hr, nucleoid_3hr, nucleoid_7hr, nucleoid_24hr, edu_1hr, edu_3hr, edu_7hr, edu_24hr)

elif simulator == "three population chase":
    ABC_plot.single_cell_posterior_predictive_chase(nucleoid_0dy, nucleoid_1dy, nucleoid_2dy, nucleoid_4dy, edu_0dy, edu_1dy, edu_2dy, edu_4dy)
# Out:
# Number of cells with nucleoid number within credible interval = 382
# Number of total cells = 382
# Proportion of cells with nucleoid number within credible intervals = 1.0
# Number of cells with mtEdU number within credible interval = 325
# Number of total cells = 382
# Proportion of cells with mtEdU number within credible intervals = 0.8507853403141361

# %% [markdown]
# We now move to computing credible intervals for higher order moments than the summary statistics we used to fit

# %%
if simulator == "three population pulse" or simulator == "dispersed three population pulse":
    ABC_plot.higher_order_pulse_moments(nucleoid_1hr, nucleoid_3hr, nucleoid_7hr, nucleoid_24hr, edu_1hr, edu_3hr, edu_7hr, edu_24hr)

elif simulator == "three population chase":
    ABC_plot.higher_order_chase_moments(nucleoid_0dy, nucleoid_1dy, nucleoid_2dy, nucleoid_4dy, edu_0dy, edu_1dy, edu_2dy, edu_4dy)
